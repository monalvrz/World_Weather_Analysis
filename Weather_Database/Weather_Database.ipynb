# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy

from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Build URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | namibe
# Processing Record 2 of Set 1 | provideniya
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | bhilwara
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | kahului
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | sur
# Processing Record 11 of Set 1 | vung tau
# Processing Record 12 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 1 | weihai
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | narsaq
# Processing Record 16 of Set 1 | mount gambier
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | chicama
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | hun
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | bichena
# Processing Record 33 of Set 1 | biak
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | iroquois falls
# Processing Record 36 of Set 1 | santiago del estero
# Processing Record 37 of Set 1 | ixtapa
# Processing Record 38 of Set 1 | cabo san lucas
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | coquimbo
# Processing Record 41 of Set 1 | kvam
# Processing Record 42 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 1 | merrill
# Processing Record 44 of Set 1 | guerrero negro
# Processing Record 45 of Set 1 | chapais
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | torzhok
# Processing Record 48 of Set 1 | tczew
# Processing Record 49 of Set 1 | isangel
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | port lincoln
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | yermakovskoye
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | maryborough
# Processing Record 10 of Set 2 | leningradskiy
# Processing Record 11 of Set 2 | butterworth
# Processing Record 12 of Set 2 | wanxian
# Processing Record 13 of Set 2 | coos bay
# Processing Record 14 of Set 2 | taltal
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | bubaque
# Processing Record 18 of Set 2 | sao joao da barra
# Processing Record 19 of Set 2 | polis
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | qaqortoq
# Processing Record 22 of Set 2 | phangnga
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | geraldton
# Processing Record 26 of Set 2 | sirjan
# Processing Record 27 of Set 2 | pochutla
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | takoradi
# Processing Record 30 of Set 2 | mahibadhoo
# Processing Record 31 of Set 2 | la asuncion
# Processing Record 32 of Set 2 | aklavik
# Processing Record 33 of Set 2 | diourbel
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | tessalit
# Processing Record 36 of Set 2 | santa rosa
# Processing Record 37 of Set 2 | nanortalik
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | blonduos
# City not found. Skipping...
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | naze
# Processing Record 42 of Set 2 | the valley
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | pijijiapan
# Processing Record 45 of Set 2 | westport
# Processing Record 46 of Set 2 | jasper
# Processing Record 47 of Set 2 | zhanaozen
# Processing Record 48 of Set 2 | wawa
# Processing Record 49 of Set 2 | barrow
# Processing Record 50 of Set 2 | rosarito
# Processing Record 1 of Set 3 | goderich
# Processing Record 2 of Set 3 | cabedelo
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | calbuco
# Processing Record 5 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 6 of Set 3 | pedernales
# Processing Record 7 of Set 3 | algeciras
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | ascoli piceno
# Processing Record 10 of Set 3 | claveria
# Processing Record 11 of Set 3 | kavieng
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | idar-oberstein
# Processing Record 14 of Set 3 | kankan
# Processing Record 15 of Set 3 | planaltina
# Processing Record 16 of Set 3 | marawi
# Processing Record 17 of Set 3 | adrar
# Processing Record 18 of Set 3 | purpe
# Processing Record 19 of Set 3 | lavrentiya
# Processing Record 20 of Set 3 | maragogi
# Processing Record 21 of Set 3 | hasaki
# Processing Record 22 of Set 3 | luderitz
# Processing Record 23 of Set 3 | itarema
# Processing Record 24 of Set 3 | teya
# Processing Record 25 of Set 3 | dzilam gonzalez
# Processing Record 26 of Set 3 | chuy
# Processing Record 27 of Set 3 | severo-kurilsk
# Processing Record 28 of Set 3 | ilulissat
# Processing Record 29 of Set 3 | shingu
# Processing Record 30 of Set 3 | baykit
# Processing Record 31 of Set 3 | rocha
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | sinazongwe
# Processing Record 34 of Set 3 | gimli
# Processing Record 35 of Set 3 | gunzenhausen
# Processing Record 36 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 3 | nikolskoye
# Processing Record 38 of Set 3 | faya
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | solano
# Processing Record 41 of Set 3 | oyama
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | oranjemund
# Processing Record 44 of Set 3 | berlevag
# Processing Record 45 of Set 3 | batagay-alyta
# Processing Record 46 of Set 3 | rawson
# Processing Record 47 of Set 3 | altagracia de orituco
# Processing Record 48 of Set 3 | fort nelson
# Processing Record 49 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 3 | chokurdakh
# Processing Record 1 of Set 4 | malmesbury
# Processing Record 2 of Set 4 | mersin
# Processing Record 3 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 4 | college
# Processing Record 5 of Set 4 | roald
# Processing Record 6 of Set 4 | yadrin
# Processing Record 7 of Set 4 | pokhara
# Processing Record 8 of Set 4 | novaya bryan
# Processing Record 9 of Set 4 | kysyl-syr
# Processing Record 10 of Set 4 | general roca
# Processing Record 11 of Set 4 | eyl
# Processing Record 12 of Set 4 | yellowknife
# Processing Record 13 of Set 4 | bengkulu
# Processing Record 14 of Set 4 | pisco
# Processing Record 15 of Set 4 | turukhansk
# Processing Record 16 of Set 4 | pangody
# Processing Record 17 of Set 4 | kirakira
# Processing Record 18 of Set 4 | constitucion
# Processing Record 19 of Set 4 | podor
# Processing Record 20 of Set 4 | sorland
# Processing Record 21 of Set 4 | esperance
# Processing Record 22 of Set 4 | oltu
# Processing Record 23 of Set 4 | dalvik
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | shepsi
# Processing Record 26 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 4 | bethel
# Processing Record 28 of Set 4 | cantanhede
# Processing Record 29 of Set 4 | matara
# Processing Record 30 of Set 4 | saint george
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | tocantinopolis
# City not found. Skipping...
# Processing Record 33 of Set 4 | qasigiannguit
# Processing Record 34 of Set 4 | boyuibe
# Processing Record 35 of Set 4 | padang
# Processing Record 36 of Set 4 | krasnoselkup
# Processing Record 37 of Set 4 | verkhniye kigi
# Processing Record 38 of Set 4 | san cristobal
# Processing Record 39 of Set 4 | el bagre
# Processing Record 40 of Set 4 | yulara
# Processing Record 41 of Set 4 | salinopolis
# Processing Record 42 of Set 4 | hualmay
# Processing Record 43 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 44 of Set 4 | caravelas
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | poso
# Processing Record 47 of Set 4 | san patricio
# Processing Record 48 of Set 4 | clyde river
# Processing Record 49 of Set 4 | sao jose da coroa grande
# Processing Record 50 of Set 4 | saint-pierre
# Processing Record 1 of Set 5 | makakilo city
# Processing Record 2 of Set 5 | nantucket
# Processing Record 3 of Set 5 | tiksi
# Processing Record 4 of Set 5 | sao filipe
# Processing Record 5 of Set 5 | san vicente
# Processing Record 6 of Set 5 | mar del plata
# Processing Record 7 of Set 5 | imbituba
# Processing Record 8 of Set 5 | vanderhoof
# Processing Record 9 of Set 5 | airai
# Processing Record 10 of Set 5 | carlsbad
# Processing Record 11 of Set 5 | ahipara
# Processing Record 12 of Set 5 | olinda
# Processing Record 13 of Set 5 | arlit
# Processing Record 14 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 17 of Set 5 | souillac
# Processing Record 18 of Set 5 | namatanai
# Processing Record 19 of Set 5 | lagoa
# Processing Record 20 of Set 5 | saint-augustin
# Processing Record 21 of Set 5 | arraial do cabo
# Processing Record 22 of Set 5 | trairi
# Processing Record 23 of Set 5 | khatanga
# Processing Record 24 of Set 5 | milton
# Processing Record 25 of Set 5 | port hawkesbury
# Processing Record 26 of Set 5 | abbeville
# Processing Record 27 of Set 5 | andenes
# Processing Record 28 of Set 5 | bereznik
# Processing Record 29 of Set 5 | matay
# Processing Record 30 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 5 | oudtshoorn
# Processing Record 32 of Set 5 | nador
# Processing Record 33 of Set 5 | garni
# Processing Record 34 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 5 | kaniama
# Processing Record 36 of Set 5 | gondar
# Processing Record 37 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 5 | hilo
# Processing Record 39 of Set 5 | sorso
# Processing Record 40 of Set 5 | vao
# Processing Record 41 of Set 5 | la ronge
# Processing Record 42 of Set 5 | taldan
# Processing Record 43 of Set 5 | rundu
# Processing Record 44 of Set 5 | dapaong
# Processing Record 45 of Set 5 | tabou
# Processing Record 46 of Set 5 | lasa
# Processing Record 47 of Set 5 | honiara
# Processing Record 48 of Set 5 | inhambane
# Processing Record 49 of Set 5 | yerbogachen
# Processing Record 50 of Set 5 | gilazi
# City not found. Skipping...
# Processing Record 1 of Set 6 | molteno
# Processing Record 2 of Set 6 | norman wells
# Processing Record 3 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 6 | stromness
# Processing Record 5 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 6 | ipora
# Processing Record 7 of Set 6 | sulangan
# Processing Record 8 of Set 6 | vila franca do campo
# Processing Record 9 of Set 6 | helena
# Processing Record 10 of Set 6 | saint anthony
# Processing Record 11 of Set 6 | cururupu
# Processing Record 12 of Set 6 | santa margherita ligure
# Processing Record 13 of Set 6 | lorengau
# Processing Record 14 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 6 | grindavik
# Processing Record 16 of Set 6 | hofn
# Processing Record 17 of Set 6 | lufilufi
# Processing Record 18 of Set 6 | saint-denis
# Processing Record 19 of Set 6 | lusaka
# Processing Record 20 of Set 6 | palmer
# Processing Record 21 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 22 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 6 | valparaiso
# Processing Record 24 of Set 6 | avera
# Processing Record 25 of Set 6 | wangqing
# Processing Record 26 of Set 6 | rio verde de mato grosso
# Processing Record 27 of Set 6 | springbok
# Processing Record 28 of Set 6 | kloulklubed
# Processing Record 29 of Set 6 | novonukutskiy
# Processing Record 30 of Set 6 | westerland
# Processing Record 31 of Set 6 | tuatapere
# Processing Record 32 of Set 6 | batemans bay
# Processing Record 33 of Set 6 | sarasota
# Processing Record 34 of Set 6 | arman
# Processing Record 35 of Set 6 | yelizovo
# Processing Record 36 of Set 6 | pevek
# Processing Record 37 of Set 6 | kununurra
# Processing Record 38 of Set 6 | punto fijo
# Processing Record 39 of Set 6 | nizhniy odes
# Processing Record 40 of Set 6 | talcahuano
# Processing Record 41 of Set 6 | oxbow
# Processing Record 42 of Set 6 | flin flon
# Processing Record 43 of Set 6 | mnogovershinnyy
# Processing Record 44 of Set 6 | mandalgovi
# Processing Record 45 of Set 6 | perevolotskiy
# Processing Record 46 of Set 6 | tarboro
# Processing Record 47 of Set 6 | raudeberg
# Processing Record 48 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 6 | cayenne
# Processing Record 50 of Set 6 | taoudenni
# Processing Record 1 of Set 7 | bakani
# Processing Record 2 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 7 | ushtobe
# Processing Record 4 of Set 7 | monteagudo
# Processing Record 5 of Set 7 | altay
# Processing Record 6 of Set 7 | bartica
# Processing Record 7 of Set 7 | conceicao do araguaia
# Processing Record 8 of Set 7 | samarai
# Processing Record 9 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 10 of Set 7 | waseca
# Processing Record 11 of Set 7 | doka
# Processing Record 12 of Set 7 | barsovo
# Processing Record 13 of Set 7 | sitka
# Processing Record 14 of Set 7 | esil
# Processing Record 15 of Set 7 | kaseda
# Processing Record 16 of Set 7 | viedma
# Processing Record 17 of Set 7 | jaramana
# City not found. Skipping...
# Processing Record 18 of Set 7 | bonthe
# Processing Record 19 of Set 7 | surt
# Processing Record 20 of Set 7 | pacific grove
# Processing Record 21 of Set 7 | mogadishu
# Processing Record 22 of Set 7 | ostrovnoy
# Processing Record 23 of Set 7 | chandausi
# Processing Record 24 of Set 7 | ossora
# Processing Record 25 of Set 7 | catamarca
# Processing Record 26 of Set 7 | kutum
# Processing Record 27 of Set 7 | anadyr
# Processing Record 28 of Set 7 | ouadda
# Processing Record 29 of Set 7 | ambulu
# Processing Record 30 of Set 7 | channel-port aux basques
# Processing Record 31 of Set 7 | mahaicony
# City not found. Skipping...
# Processing Record 32 of Set 7 | hovd
# Processing Record 33 of Set 7 | shimoda
# Processing Record 34 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 35 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 7 | mehamn
# Processing Record 37 of Set 7 | kangaatsiaq
# Processing Record 38 of Set 7 | ust-koksa
# Processing Record 39 of Set 7 | turayf
# Processing Record 40 of Set 7 | barabinsk
# Processing Record 41 of Set 7 | swan hill
# Processing Record 42 of Set 7 | kuala selangor
# Processing Record 43 of Set 7 | tucuma
# Processing Record 44 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 7 | williamsburg
# Processing Record 46 of Set 7 | doha
# Processing Record 47 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 7 | saldanha
# Processing Record 49 of Set 7 | el carmen de bolivar
# Processing Record 50 of Set 7 | illela
# Processing Record 1 of Set 8 | owase
# Processing Record 2 of Set 8 | inirida
# Processing Record 3 of Set 8 | rio grande
# Processing Record 4 of Set 8 | danjiangkou
# Processing Record 5 of Set 8 | okhotsk
# Processing Record 6 of Set 8 | kanniyakumari
# Processing Record 7 of Set 8 | cabo rojo
# Processing Record 8 of Set 8 | caraquet
# Processing Record 9 of Set 8 | bichura
# Processing Record 10 of Set 8 | lompoc
# Processing Record 11 of Set 8 | villazon
# Processing Record 12 of Set 8 | aras
# Processing Record 13 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 8 | izumo
# Processing Record 15 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 8 | aliwal north
# Processing Record 17 of Set 8 | palladam
# Processing Record 18 of Set 8 | diamantino
# Processing Record 19 of Set 8 | sandviken
# Processing Record 20 of Set 8 | majenang
# Processing Record 21 of Set 8 | campeche
# Processing Record 22 of Set 8 | quatre cocos
# Processing Record 23 of Set 8 | simao
# Processing Record 24 of Set 8 | navahrudak
# Processing Record 25 of Set 8 | komsomolskiy
# Processing Record 26 of Set 8 | chara
# Processing Record 27 of Set 8 | miyako
# Processing Record 28 of Set 8 | kismayo
# Processing Record 29 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 8 | sobolevo
# Processing Record 31 of Set 8 | okha
# Processing Record 32 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 8 | vanavara
# Processing Record 35 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 8 | bayan
# Processing Record 37 of Set 8 | porto belo
# Processing Record 38 of Set 8 | tuktoyaktuk
# Processing Record 39 of Set 8 | torbay
# Processing Record 40 of Set 8 | camargo
# Processing Record 41 of Set 8 | touros
# Processing Record 42 of Set 8 | lazaro cardenas
# Processing Record 43 of Set 8 | benghazi
# Processing Record 44 of Set 8 | mankono
# Processing Record 45 of Set 8 | hede
# Processing Record 46 of Set 8 | tomigusuku
# Processing Record 47 of Set 8 | kalmunai
# Processing Record 48 of Set 8 | ketchikan
# Processing Record 49 of Set 8 | natal
# Processing Record 50 of Set 8 | asau
# Processing Record 1 of Set 9 | manicore
# Processing Record 2 of Set 9 | alyangula
# Processing Record 3 of Set 9 | dingle
# Processing Record 4 of Set 9 | ternate
# Processing Record 5 of Set 9 | elizabeth city
# Processing Record 6 of Set 9 | obo
# Processing Record 7 of Set 9 | kharp
# Processing Record 8 of Set 9 | victoria
# Processing Record 9 of Set 9 | thompson
# Processing Record 10 of Set 9 | rodez
# Processing Record 11 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 9 | tarakan
# Processing Record 13 of Set 9 | boca do acre
# Processing Record 14 of Set 9 | gat
# Processing Record 15 of Set 9 | tukums
# Processing Record 16 of Set 9 | yavaros
# Processing Record 17 of Set 9 | abha
# Processing Record 18 of Set 9 | biograd na moru
# Processing Record 19 of Set 9 | morehead
# Processing Record 20 of Set 9 | zbarazh
# Processing Record 21 of Set 9 | gushikawa
# Processing Record 22 of Set 9 | mayahi
# Processing Record 23 of Set 9 | digby
# Processing Record 24 of Set 9 | naliya
# Processing Record 25 of Set 9 | meerzorg
# City not found. Skipping...
# Processing Record 26 of Set 9 | russell
# Processing Record 27 of Set 9 | togur
# Processing Record 28 of Set 9 | peoria
# Processing Record 29 of Set 9 | koumac
# Processing Record 30 of Set 9 | gibraltar
# Processing Record 31 of Set 9 | sorkjosen
# Processing Record 32 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | smirnykh
# Processing Record 34 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 9 | lamar
# Processing Record 36 of Set 9 | veraval
# Processing Record 37 of Set 9 | salalah
# Processing Record 38 of Set 9 | kargasok
# Processing Record 39 of Set 9 | ozinki
# Processing Record 40 of Set 9 | enugu
# Processing Record 41 of Set 9 | mount isa
# Processing Record 42 of Set 9 | manuk mangkaw
# Processing Record 43 of Set 9 | jinchang
# Processing Record 44 of Set 9 | port-gentil
# Processing Record 45 of Set 9 | ponta delgada
# Processing Record 46 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 9 | muscat
# Processing Record 48 of Set 9 | grand-lahou
# Processing Record 49 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 9 | vardo
# Processing Record 1 of Set 10 | sagone
# Processing Record 2 of Set 10 | beloha
# Processing Record 3 of Set 10 | cabras
# Processing Record 4 of Set 10 | burnie
# Processing Record 5 of Set 10 | lucapa
# Processing Record 6 of Set 10 | berezovyy
# Processing Record 7 of Set 10 | angoram
# Processing Record 8 of Set 10 | beisfjord
# Processing Record 9 of Set 10 | angola
# Processing Record 10 of Set 10 | pangnirtung
# Processing Record 11 of Set 10 | buritis
# Processing Record 12 of Set 10 | winslow
# Processing Record 13 of Set 10 | henties bay
# Processing Record 14 of Set 10 | umm lajj
# Processing Record 15 of Set 10 | shiraz
# Processing Record 16 of Set 10 | diego de almagro
# Processing Record 17 of Set 10 | tamiahua
# Processing Record 18 of Set 10 | pedasi
# Processing Record 19 of Set 10 | mana
# Processing Record 20 of Set 10 | emerald
# Processing Record 21 of Set 10 | fuyu
# Processing Record 22 of Set 10 | usinsk
# Processing Record 23 of Set 10 | kavaratti
# Processing Record 24 of Set 10 | anori
# Processing Record 25 of Set 10 | skegness
# Processing Record 26 of Set 10 | amahai
# Processing Record 27 of Set 10 | grand forks
# Processing Record 28 of Set 10 | buenos aires
# Processing Record 29 of Set 10 | wembley
# Processing Record 30 of Set 10 | sham churasi
# Processing Record 31 of Set 10 | kaitangata
# Processing Record 32 of Set 10 | digras
# Processing Record 33 of Set 10 | havre-saint-pierre
# Processing Record 34 of Set 10 | sandpoint
# Processing Record 35 of Set 10 | prince rupert
# Processing Record 36 of Set 10 | huarmey
# Processing Record 37 of Set 10 | batticaloa
# Processing Record 38 of Set 10 | irbeyskoye
# Processing Record 39 of Set 10 | eenhana
# Processing Record 40 of Set 10 | bayevo
# Processing Record 41 of Set 10 | korla
# Processing Record 42 of Set 10 | mosetse
# Processing Record 43 of Set 10 | kiama
# Processing Record 44 of Set 10 | meadow lake
# Processing Record 45 of Set 10 | lubumbashi
# Processing Record 46 of Set 10 | poplar bluff
# Processing Record 47 of Set 10 | pelym
# Processing Record 48 of Set 10 | prainha
# Processing Record 49 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 10 | ormara
# Processing Record 1 of Set 11 | joao pinheiro
# Processing Record 2 of Set 11 | mamit
# Processing Record 3 of Set 11 | novorzhev
# Processing Record 4 of Set 11 | moree
# Processing Record 5 of Set 11 | isiro
# Processing Record 6 of Set 11 | labuhan
# Processing Record 7 of Set 11 | cidreira
# Processing Record 8 of Set 11 | santa cruz
# Processing Record 9 of Set 11 | birjand
# Processing Record 10 of Set 11 | axim
# Processing Record 11 of Set 11 | ishigaki
# Processing Record 12 of Set 11 | powell
# Processing Record 13 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 14 of Set 11 | chake chake
# Processing Record 15 of Set 11 | mayo
# Processing Record 16 of Set 11 | matadi
# Processing Record 17 of Set 11 | nizhniy baskunchak
# Processing Record 18 of Set 11 | san pedro
# Processing Record 19 of Set 11 | harper
# Processing Record 20 of Set 11 | chitral
# Processing Record 21 of Set 11 | a
# City not found. Skipping...
# Processing Record 22 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 11 | kuminskiy
# Processing Record 24 of Set 11 | camacupa
# Processing Record 25 of Set 11 | egvekinot
# Processing Record 26 of Set 11 | abu kamal
# Processing Record 27 of Set 11 | north bend
# Processing Record 28 of Set 11 | teguise
# Processing Record 29 of Set 11 | yaan
# Processing Record 30 of Set 11 | great falls
# Processing Record 31 of Set 11 | huejuquilla el alto
# Processing Record 32 of Set 11 | north adams
# Processing Record 33 of Set 11 | binabalian
# Processing Record 34 of Set 11 | zhaotong
# Processing Record 35 of Set 11 | zhangjiakou
# Processing Record 36 of Set 11 | te anau
# Processing Record 37 of Set 11 | nyzhni sirohozy
# Processing Record 38 of Set 11 | dekar
# Processing Record 39 of Set 11 | brooks
# Processing Record 40 of Set 11 | aranos
# Processing Record 41 of Set 11 | praia
# Processing Record 42 of Set 11 | mezen
# Processing Record 43 of Set 11 | kiunga
# Processing Record 44 of Set 11 | chore
# City not found. Skipping...
# Processing Record 45 of Set 11 | camana
# Processing Record 46 of Set 11 | moberly
# Processing Record 47 of Set 11 | zhangye
# Processing Record 48 of Set 11 | luau
# Processing Record 49 of Set 11 | kemptville
# Processing Record 50 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 12 | cherskiy
# Processing Record 2 of Set 12 | agarak
# Processing Record 3 of Set 12 | port-cartier
# Processing Record 4 of Set 12 | belle fourche
# Processing Record 5 of Set 12 | grand gaube
# Processing Record 6 of Set 12 | yatou
# Processing Record 7 of Set 12 | half moon bay
# Processing Record 8 of Set 12 | kivertsi
# Processing Record 9 of Set 12 | teguldet
# Processing Record 10 of Set 12 | harrislee
# Processing Record 11 of Set 12 | kolokani
# Processing Record 12 of Set 12 | beloslav
# Processing Record 13 of Set 12 | berdigestyakh
# Processing Record 14 of Set 12 | bathsheba
# Processing Record 15 of Set 12 | kulhudhuffushi
# Processing Record 16 of Set 12 | enid
# Processing Record 17 of Set 12 | muli
# Processing Record 18 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 12 | broome
# Processing Record 20 of Set 12 | nyuksenitsa
# Processing Record 21 of Set 12 | longview
# Processing Record 22 of Set 12 | port augusta
# Processing Record 23 of Set 12 | basoko
# Processing Record 24 of Set 12 | huanuco
# Processing Record 25 of Set 12 | gizo
# Processing Record 26 of Set 12 | eisenerz
# Processing Record 27 of Set 12 | pringsewu
# Processing Record 28 of Set 12 | canandaigua
# Processing Record 29 of Set 12 | buchanan
# Processing Record 30 of Set 12 | tshikapa
# Processing Record 31 of Set 12 | shediac
# Processing Record 32 of Set 12 | mairana
# Processing Record 33 of Set 12 | gumdag
# Processing Record 34 of Set 12 | thaton
# Processing Record 35 of Set 12 | qandala
# Processing Record 36 of Set 12 | mildura
# Processing Record 37 of Set 12 | vila velha
# Processing Record 38 of Set 12 | pingdu
# Processing Record 39 of Set 12 | eyemouth
# Processing Record 40 of Set 12 | bonavista
# Processing Record 41 of Set 12 | kaeo
# Processing Record 42 of Set 12 | sitio novo do tocantins
# Processing Record 43 of Set 12 | laguna
# Processing Record 44 of Set 12 | hokitika
# Processing Record 45 of Set 12 | mayaky
# Processing Record 46 of Set 12 | kirando
# Processing Record 47 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 48 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 49 of Set 12 | pahalgam
# Processing Record 50 of Set 12 | mbeya
# Processing Record 1 of Set 13 | nyurba
# Processing Record 2 of Set 13 | muros
# Processing Record 3 of Set 13 | ancud
# Processing Record 4 of Set 13 | zhigansk
# Processing Record 5 of Set 13 | anahuac
# Processing Record 6 of Set 13 | melendugno
# Processing Record 7 of Set 13 | sorong
# Processing Record 8 of Set 13 | bandiagara
# Processing Record 9 of Set 13 | port blair
# Processing Record 10 of Set 13 | santa isabel do rio negro
# Processing Record 11 of Set 13 | taburao
# City not found. Skipping...
# Processing Record 12 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 13 | teknaf
# Processing Record 14 of Set 13 | wadi maliz
# Processing Record 15 of Set 13 | echirolles
# Processing Record 16 of Set 13 | tipuani
# Processing Record 17 of Set 13 | jayanca
# Processing Record 18 of Set 13 | campina verde
# Processing Record 19 of Set 13 | carauari
# Processing Record 20 of Set 13 | zhigalovo
# Processing Record 21 of Set 13 | marsh harbour
# Processing Record 22 of Set 13 | balikpapan
# Processing Record 23 of Set 13 | beringovskiy
# Processing Record 24 of Set 13 | saint-ambroise
# Processing Record 25 of Set 13 | cockburn town
# Processing Record 26 of Set 13 | progreso
# Processing Record 27 of Set 13 | alexandria
# Processing Record 28 of Set 13 | noumea
# Processing Record 29 of Set 13 | porto novo
# Processing Record 30 of Set 13 | beliator
# Processing Record 31 of Set 13 | sembe
# Processing Record 32 of Set 13 | erdaojiang
# Processing Record 33 of Set 13 | beipiao
# Processing Record 34 of Set 13 | port macquarie
# Processing Record 35 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 13 | evensk
# Processing Record 37 of Set 13 | port-de-bouc
# Processing Record 38 of Set 13 | haines junction
# Processing Record 39 of Set 13 | bilma
# Processing Record 40 of Set 13 | seoul
# Processing Record 41 of Set 13 | ler
# Processing Record 42 of Set 13 | kalia
# Processing Record 43 of Set 13 | chiang khong
# Processing Record 44 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 13 | jijiga
# Processing Record 46 of Set 13 | kenai
# Processing Record 47 of Set 13 | miri
# Processing Record 48 of Set 13 | firsanovka
# Processing Record 49 of Set 13 | sisimiut
# Processing Record 50 of Set 13 | bucerias
# Processing Record 1 of Set 14 | abdulino
# Processing Record 2 of Set 14 | snasa
# Processing Record 3 of Set 14 | palanga
# Processing Record 4 of Set 14 | rafai
# Processing Record 5 of Set 14 | richards bay
# Processing Record 6 of Set 14 | boyolangu
# Processing Record 7 of Set 14 | dublin
# Processing Record 8 of Set 14 | marzuq
# Processing Record 9 of Set 14 | skjervoy
# Processing Record 10 of Set 14 | tuy hoa
# Processing Record 11 of Set 14 | aykhal
# Processing Record 12 of Set 14 | corrente
# Processing Record 13 of Set 14 | kieta
# Processing Record 14 of Set 14 | imeni poliny osipenko
# Processing Record 15 of Set 14 | coahuayana
# Processing Record 16 of Set 14 | dunedin
# Processing Record 17 of Set 14 | tura
# Processing Record 18 of Set 14 | areka
# Processing Record 19 of Set 14 | lata
# Processing Record 20 of Set 14 | emilio carranza
# Processing Record 21 of Set 14 | enzan
# Processing Record 22 of Set 14 | henzada
# City not found. Skipping...
# Processing Record 23 of Set 14 | lebanon
# Processing Record 24 of Set 14 | luba
# Processing Record 25 of Set 14 | vavuniya
# Processing Record 26 of Set 14 | fare
# Processing Record 27 of Set 14 | tupik
# Processing Record 28 of Set 14 | noyabrsk
# Processing Record 29 of Set 14 | matanzas
# Processing Record 30 of Set 14 | vangaindrano
# Processing Record 31 of Set 14 | maniwaki
# Processing Record 32 of Set 14 | krasnovishersk
# Processing Record 33 of Set 14 | passo de camaragibe
# Processing Record 34 of Set 14 | tilichiki
# Processing Record 35 of Set 14 | aitape
# Processing Record 36 of Set 14 | tobermory
# Processing Record 37 of Set 14 | jizan
# Processing Record 38 of Set 14 | danville
# Processing Record 39 of Set 14 | damavand
# Processing Record 40 of Set 14 | clinton
# Processing Record 41 of Set 14 | cap malheureux
# Processing Record 42 of Set 14 | komyshuvakha
# Processing Record 43 of Set 14 | borogontsy
# Processing Record 44 of Set 14 | jalu
# Processing Record 45 of Set 14 | hervey bay
# Processing Record 46 of Set 14 | ziyang
# Processing Record 47 of Set 14 | kamenka
# Processing Record 48 of Set 14 | tadine
# Processing Record 49 of Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 14 | sakaiminato
# Processing Record 1 of Set 15 | sibu
# Processing Record 2 of Set 15 | novyy urengoy
# Processing Record 3 of Set 15 | casablanca
# Processing Record 4 of Set 15 | karratha
# Processing Record 5 of Set 15 | loukhi
# Processing Record 6 of Set 15 | ryotsu
# Processing Record 7 of Set 15 | healdsburg
# Processing Record 8 of Set 15 | high level
# Processing Record 9 of Set 15 | gazanjyk
# Processing Record 10 of Set 15 | puerto madryn
# Processing Record 11 of Set 15 | kefamenanu
# Processing Record 12 of Set 15 | vaitape
# Processing Record 13 of Set 15 | bukama
# Processing Record 14 of Set 15 | sola
# Processing Record 15 of Set 15 | phan thiet
# Processing Record 16 of Set 15 | eureka
# Processing Record 17 of Set 15 | sinnamary
# Processing Record 18 of Set 15 | parras
# City not found. Skipping...
# Processing Record 19 of Set 15 | kyzyl
# Processing Record 20 of Set 15 | amga
# Processing Record 21 of Set 15 | santa vitoria do palmar
# Processing Record 22 of Set 15 | utmanzai
# Processing Record 23 of Set 15 | kashi
# Processing Record 24 of Set 15 | tateyama
# Processing Record 25 of Set 15 | mongoumba
# Processing Record 26 of Set 15 | aloleng
# Processing Record 27 of Set 15 | carutapera
# Processing Record 28 of Set 15 | sampit
# Processing Record 29 of Set 15 | sciacca
# Processing Record 30 of Set 15 | zinder
# Processing Record 31 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 32 of Set 15 | taklisah
# Processing Record 33 of Set 15 | kichera
# Processing Record 34 of Set 15 | lingao
# Processing Record 35 of Set 15 | arak
# Processing Record 36 of Set 15 | yining
# Processing Record 37 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 38 of Set 15 | zabid
# Processing Record 39 of Set 15 | mint hill
# Processing Record 40 of Set 15 | hobyo
# Processing Record 41 of Set 15 | rio gallegos
# Processing Record 42 of Set 15 | acaponeta
# Processing Record 43 of Set 15 | hirara
# Processing Record 44 of Set 15 | puttur
# Processing Record 45 of Set 15 | hailey
# Processing Record 46 of Set 15 | coihaique
# Processing Record 47 of Set 15 | ocean city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Namibe -15.1961   12.1522     61.38        90          54
# 1    Provideniya  64.3833 -173.3000     48.36       100         100
# 2         Albany  42.6001  -73.9662     81.68        53          83
# 3       Bhilwara  25.3500   74.6333     76.59        91          99
# 4          Bluff -46.6000  168.3333     41.65        80          99
# ..           ...      ...       ...       ...       ...         ...
# 680       Hirara  24.8000  125.2833     82.26        94          75
# 681       Puttur  12.7667   75.2167     77.11        85          97
# 682       Hailey  43.5196 -114.3153     91.89        36           0
# 683    Coihaique -45.5752  -72.0662     44.55        76          75
# 684   Ocean City  39.2776  -74.5746     88.05        76         100
#
#      Wind Speed Country Current Description
# 0          8.57      AO       broken clouds
# 1          8.99      RU     overcast clouds
# 2          9.35      US       broken clouds
# 3          8.41      IN          light rain
# 4          9.69      NZ     overcast clouds
# ..          ...     ...                 ...
# 680        2.30      JP       broken clouds
# 681        6.44      IN     overcast clouds
# 682       10.36      US           clear sky
# 683        6.91      CL       broken clouds
# 684        4.00      US     overcast clouds
#
# [685 rows x 9 columns]

# %%
city_data_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[city_data_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Namibe      AO -15.1961   12.1522     61.38        90          54
# 1  Provideniya      RU  64.3833 -173.3000     48.36       100         100
# 2       Albany      US  42.6001  -73.9662     81.68        53          83
# 3     Bhilwara      IN  25.3500   74.6333     76.59        91          99
# 4        Bluff      NZ -46.6000  168.3333     41.65        80          99
# 5       Dikson      RU  73.5069   80.5464     43.97        93         100
# 6    Saskylakh      RU  71.9167  114.0833     43.66        69         100
# 7      Kahului      US  20.8947 -156.4700     91.42        49          20
# 8        Kapaa      US  22.0752 -159.3190     84.18        71          20
# 9          Sur      OM  22.5667   59.5289     89.53        59         100
#
#    Wind Speed Current Description
# 0        8.57       broken clouds
# 1        8.99     overcast clouds
# 2        9.35       broken clouds
# 3        8.41          light rain
# 4        9.69     overcast clouds
# 5       19.44     overcast clouds
# 6        7.09     overcast clouds
# 7       28.77          few clouds
# 8       14.97          few clouds
# 9        4.12     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
